# %%
# %run "Almgren-Chriss-Market.ipynb"
# %run "Real-Market-Data.ipynb"

# %% [markdown]
# ## Visualization of different types of market generated
#
# This file is dedicated to visualizing different types of market that are generated based on and extended from Almgren-Chriss Trading Model

# %% [markdown]
# ### Flat Market

# %%
plt.plot(t, S_flat)
plt.xlabel('Time Steps')
plt.ylabel('Flat Price before random volativity')
plt.show()

# %% [markdown]
# ### Cosine Market

# %%
plt.plot(t, S_cos)
plt.xlabel('Time Steps')
plt.ylabel('Cosine Price before random volativity')
plt.show()

# %% [markdown]
# ### Cosine Market with Volatility factor

# %%
plt.plot(t, S_vcos)
plt.xlabel('Time Steps')
plt.ylabel('Cosine Price after random volativity')
plt.show()

# %% [markdown]
# ## Real market price data from 'AAPL' Stock

# %%
S_real_AAPL, t_real_AAPL = real_stock_price('AAPL')

# %%
plt.plot(t_real_AAPL, S_real_AAPL)
plt.xlabel('Time Steps')
plt.ylabel('AAPL last 200 prices')
plt.show()

# %% [markdown]
# ## Real market closing prices data from 'MSFT' Stock

# %%
S_real_MSFT, _ = real_stock_price('MSFT', 300, '4. close')

# %%
plt.plot(S_real_MSFT)
plt.xlabel('Time Steps')
plt.ylabel('MSFT last 300 closing prices')
plt.show()
